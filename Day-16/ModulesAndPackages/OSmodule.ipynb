# %% [markdown]
# # Python OS Module
#
# The os module in Python provides a way of interacting with the operating system. It provides a way to access and manipulate files and directories, start and stop processes, get information about the system, and more.
#
# ## Working with Files and Directories
#
# Let's explore the `os` module and its various functions and methods that support working with files and directories.
#
# - `os.getcwd()`: Get the current working directory
# - `os.mkdir('path')`: Create a new directory
# - `os.chdir('path')`: Change the current working directory
# - `os.listdir('path')`: List the contents of a directory
# - `os.rename('old_name', 'new_name)`: Rename a file or a directory
# - `os.remove('file_to_delete')`: Remove a file
# - `os.rmdir('directory_to_delete')`: Remove a directory
# - `os.path.dirname('path')`: Returns the name of the directory containing pathname path
# - `os.path.exists('path')`: Checks if the path already exists, if so returns True

# %%
import os

# %%
os.getcwd()
# Out:
# '/home/shailesh/Desktop/education/DSML-13/Day-15/ModulesAndPackages'

# %%
os.mkdir("test")

# %%
os.chdir("test")

# %%
os.getcwd()
# Out:
# '/home/shailesh/Desktop/education/DSML-13/Day-15/ModulesAndPackages/test'

# %%
os.chdir("..")

# %%
os.getcwd()
# Out:
# '/home/shailesh/Desktop/education/DSML-13/Day-15/ModulesAndPackages'

# %%
if os.path.exists("test"):
    pass
else:
    print("file Doesn't exist")

# %%
# Make folder without error
os.makedirs("test", exist_ok=True)

# %%
os.path.join("test", "file.txt")
# Out:
# 'test/file.txt'

# %%
os.listdir()
# Out:
# ['test', 'OSmodule.ipynb', '.ipynb_checkpoints']

# %%
os.listdrives()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 os.listdrives()
#
# AttributeError: module 'os' has no attribute 'listdrives'

# %%
os.rmdir("test")

# %%
os.remove("test.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 os.remove("test.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %% [markdown]
# ## Working with Environment Variables
#
# The `os` module provides functions for working with environment variables. Here are some of the most commonly used functions:
#
# - `os.getenv('var_name')`: Get the value of an Environment Variable
# - `os.environ['var_name'] = 'var_value'`: Set the Value of an Environment Variable

# %%
os.environ
# Out:
# environ{'SHELL': '/bin/bash',
#         'QT_ACCESSIBILITY': '1',
#         'COLORTERM': 'truecolor',
#         'PYENV_SHELL': 'bash',
#         'XDG_CONFIG_DIRS': '/etc/xdg/xdg-ubuntu:/etc/xdg',
#         'VSCODE_DEBUGPY_ADAPTER_ENDPOINTS': '/home/shailesh/.vscode/extensions/ms-python.debugpy-2026.6.0-linux-x64/.noConfigDebugAdapterEndpoints/endpoint-8d0d8bcaac81c9fb.txt',
#         'XDG_MENU_PREFIX': 'gnome-',
#         'TERM_PROGRAM_VERSION': '1.133.0',
#         'GNOME_DESKTOP_SESSION_ID': 'this-is-deprecated',
#         'COPILOT_DEBUG_NONCE': '3a9ad20be94e4c5d58f8265381d36a1f',
#         'QT_IM_MODULES': 'wayland;ibus',
#         'SSH_AUTH_SOCK': '/run/user/1000/gcr/ssh',
#         'MEMORY_PRESSURE_WRITE': 'c29tZSAyMDAwMDAgMjAwMDAwMAA=',
#         'PYDEVD_DISABLE_FILE_VALIDATION': '1',
#         'XMODIFIERS': '@im=ibus',
#         'DESKTOP_SESSION': 'ubuntu',
#         'GTK_MODULES': 'gail:atk-bridge',
#         'PWD': '/home/shailesh/Desktop/education/DSML-13',
#         'XDG_SESSION_DESKTOP': 'ubuntu',
#         'LOGNAME': 'shailesh',
#         'XDG_SESSION_TYPE': 'wayland',
#         'GPG_AGENT_INFO': '/run/user/1000/gnupg/S.gpg-agent:0:1',
#         'SYSTEMD_EXEC_PID': '6006',
#         'BUNDLED_DEBUGPY_PATH': '/home/shailesh/.vscode/extensions/ms-python.debugpy-2026.6.0-linux-x64/bundled/libs/debugpy',
#         'XAUTHORITY': '/run/user/1000/.mutter-Xwaylandauth.MWAKT3',
#         'VSCODE_GIT_ASKPASS_NODE': '/usr/share/code/code',
#         'GJS_DEBUG_TOPICS': 'JS ERROR;JS LOG',
#         'HOME': '/home/shailesh',
#         'USERNAME': 'shailesh',
#         'LANG': 'en_US.UTF-8',
#         'LS_COLORS': 'rs=0:di=01;34:ln=01;36:mh=00:pi=40;33:so=01;35:do=01;35:bd=40;33;01:cd=40;33;01:or=40;31;01:mi=00:su=37;41:sg=30;43:ca=00:tw=30;42:ow=34;42:st=37;44:ex=01;32:*.tar=01;31:*.tgz=01;31:*.arc=01;31:*.arj=01;31:*.taz=01;31:*.lha=01;31:*.lz4=01;31:*.lzh=01;31:*.lzma=01;31:*.tlz=01;31:*.txz=01;31:*.tzo=01;31:*.t7z=01;31:*.zip=01;31:*.z=01;31:*.dz=01;31:*.gz=01;31:*.lrz=01;31:*.lz=01;31:*.lzo=01;31:*.xz=01;31:*.zst=01;31:*.tzst=01;31:*.bz2=01;31:*.bz=01;31:*.tbz=01;31:*.tbz2=01;31:*.tz=01;31:*.deb=01;31:*.rpm=01;31:*.jar=01;31:*.war=01;31:*.ear=01;31:*.sar=01;31:*.rar=01;31:*.alz=01;31:*.ace=01;31:*.zoo=01;31:*.cpio=01;31:*.7z=01;31:*.rz=01;31:*.cab=01;31:*.wim=01;31:*.swm=01;31:*.dwm=01;31:*.esd=01;31:*.avif=01;35:*.jpg=01;35:*.jpeg=01;35:*.mjpg=01;35:*.mjpeg=01;35:*.gif=01;35:*.bmp=01;35:*.pbm=01;35:*.pgm=01;35:*.ppm=01;35:*.tga=01;35:*.xbm=01;35:*.xpm=01;35:*.tif=01;35:*.tiff=01;35:*.png=01;35:*.svg=01;35:*.svgz=01;35:*.mng=01;35:*.pcx=01;35:*.mov=01;35:*.mpg=01;35:*.mpeg=01;35:*.m2v=01;35:*.mkv=01;35:*.webm=01;35:*.webp=01;35:*.ogm=01;35:*.mp4=01;35:*.m4v=01;35:*.mp4v=01;35:*.vob=01;35:*.qt=01;35:*.nuv=01;35:*.wmv=01;35:*.asf=01;35:*.rm=01;35:*.rmvb=01;35:*.flc=01;35:*.avi=01;35:*.fli=01;35:*.flv=01;35:*.gl=01;35:*.dl=01;35:*.xcf=01;35:*.xwd=01;35:*.yuv=01;35:*.cgm=01;35:*.emf=01;35:*.ogv=01;35:*.ogx=01;35:*.aac=00;36:*.au=00;36:*.flac=00;36:*.m4a=00;36:*.mid=00;36:*.midi=00;36:*.mka=00;36:*.mp3=00;36:*.mpc=00;36:*.ogg=00;36:*.ra=00;36:*.wav=00;36:*.oga=00;36:*.opus=00;36:*.spx=00;36:*.xspf=00;36:*~=00;90:*#=00;90:*.bak=00;90:*.old=00;90:*.orig=00;90:*.part=00;90:*.rej=00;90:*.swp=00;90:*.tmp=00;90:*.dpkg-dist=00;90:*.dpkg-old=00;90:*.ucf-dist=00;90:*.ucf-new=00;90:*.ucf-old=00;90:*.rpmnew=00;90:*.rpmorig=00;90:*.rpmsave=00;90:',
#         'XDG_CURRENT_DESKTOP': 'ubuntu:GNOME',
#         'VIRTUAL_ENV': '/home/shailesh/Desktop/education/.venv',
#         'PYTHONSTARTUP': '/home/shailesh/.config/Code/User/workspaceStorage/8f9de4b167e463b61bfa0f43fbebe44f/ms-python.python/pythonrc.py',
#         'MEMORY_PRESSURE_WATCH': '/sys/fs/cgroup/user.slice/user-1000.slice/user@1000.service/session.slice/org.gnome.Shell@ubuntu.service/memory.pressure',
#         'WAYLAND_DISPLAY': 'wayland-0',
#         'GIT_ASKPASS': '/usr/share/code/resources/app/extensions/git/dist/askpass.sh',
#         'INVOCATION_ID': '955c9b5c1cc7428093b63e27d3c0dde1',
#         'MANAGERPID': '5360',
#         'CHROME_DESKTOP': 'code.desktop',
#         'GJS_DEBUG_OUTPUT': 'stderr',
#         'VSCODE_GIT_ASKPASS_EXTRA_ARGS': '',
#         'GNOME_SETUP_DISPLAY': 'unix:/tmp/.X11-unix/X1',
#         'VSCODE_PYTHON_AUTOACTIVATE_GUARD': '1',
#         'LESSCLOSE': '/usr/bin/lesspipe %s %s',
#         'XDG_SESSION_CLASS': 'user',
#         'PYTHONPATH': 'home/shailesh/.cache/pypoetry/virtualenvs/tactix-yuBQfSTb-py3.11/lib/python3.11/site-packages:home/shailesh/.cache/pypoetry/virtualenvs/tactix-yuBQfSTb-py3.11/lib/python3.11/site-packages:',
#         'TERM': 'xterm-color',
#         'PYTHON_BASIC_REPL': '1',
#         'LESSOPEN': '| /usr/bin/lesspipe %s',
#         'USER': 'shailesh',
#         'VSCODE_GIT_IPC_HANDLE': '/run/user/1000/vscode-git-7fe5548d45.sock',
#         'DISPLAY': ':0',
#         'SHLVL': '1',
#         'QT_IM_MODULE': 'ibus',
#         'VIRTUAL_ENV_PROMPT': '(.venv) ',
#         'MANAGERPIDFDID': '45424',
#         'FC_FONTATIONS': '1',
#         'XDG_RUNTIME_DIR': '/run/user/1000',
#         'PS1': '\\[\x1b]633;A\x07\\]((.venv) ) \\[\x1b]633;A\x07\\]\\[\\e]0;\\u@\\h: \\w\\a\\]${debian_chroot:+($debian_chroot)}\\[\\033\\]\\u@\\h\\[\\033\\]:\\[\\033\\]\\w\\[\\033\\]\\$ \\[\x1b]633;B\x07\\]\\[\x1b]633;B\x07\\]',
#         'PYENV_ROOT': '/home/shailesh/.pyenv',
#         'DEBUGINFOD_URLS': 'https://debuginfod.ubuntu.com ',
#         'IM_CONFIG_ENTRY': 'profile',
#         'VSCODE_GIT_ASKPASS_MAIN': '/usr/share/code/resources/app/extensions/git/dist/askpass-main.js',
#         'JOURNAL_STREAM': '10:22275',
#         'XDG_DATA_DIRS': '/usr/share/ubuntu:/usr/share/gnome:/usr/local/share/:/usr/share/:/var/lib/snapd/desktop',
#         'GDK_BACKEND': 'wayland',
#         'PATH': '/home/shailesh/Desktop/education/.venv/bin:/home/shailesh/.pyenv/shims:/home/shailesh/.pyenv/bin:/home/shailesh/.config/Code/User/globalStorage/github.copilot-chat/debugCommand:/home/shailesh/.config/Code/User/globalStorage/github.copilot-chat/copilotCli:/home/shailesh/.local/bin:/home/shailesh/.pyenv/bin:/home/shailesh/.local/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/snap/bin:/home/shailesh/.vscode/extensions/ms-python.debugpy-2026.6.0-linux-x64/bundled/scripts/noConfigScripts',
#         'GDMSESSION': 'ubuntu',
#         'XDG_SESSION_EXTRA_DEVICE_ACCESS': 'render:accel',
#         'DBUS_SESSION_BUS_ADDRESS': 'unix:path=/run/user/1000/bus',
#         'GIO_LAUNCHED_DESKTOP_FILE_PID': '67624',
#         'GIO_LAUNCHED_DESKTOP_FILE': '/usr/share/applications/code.desktop',
#         'TERM_PROGRAM': 'vscode',
#         '_': '/home/shailesh/Desktop/education/.venv/bin/jupyter',
#         'JPY_SESSION_NAME': '/home/shailesh/Desktop/education/DSML-13/Day-16/ModulesAndPackages/OSmodule.ipynb',
#         'JPY_PARENT_PID': '119033',
#         'PYDEVD_USE_FRAME_EVAL': 'NO',
#         'CLICOLOR': '1',
#         'FORCE_COLOR': '1',
#         'CLICOLOR_FORCE': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %%
os.environ["SECRETPass"] = "adgawv9vawsv87wSA57BVA)beV"

# %%
os.getenv("SECRETPass")
# Out:
# 'adgawv9vawsv87wSA57BVA)beV'

# %%
os.getenv("OneDrive")
